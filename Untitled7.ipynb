# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
(ds_train, ds_test), info = tfds.load('imdb_reviews', split = ['train', 'test'], as_supervised = True, with_info = True)
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-aac4de7aee86> in <module>
# ----> 1 (ds_train, ds_test), info = tfds.load('imdb_reviews', split = ['train', 'test'], as_supervised = True, with_info = True)
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     331   if download:
#     332     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 333     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     334
#     335   if as_dataset_kwargs is None:
#
# ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config)
# ...
