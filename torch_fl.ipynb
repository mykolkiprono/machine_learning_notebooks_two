# %%
import os

import imageio
import torch

import matplotlib.pyplot as plt

# %%
img_arr = imageio.imread("/home/mikey/Downloads/flowers/rose/229488796_21ac6ee16d_n.jpg")

# in H,W,C structure need to converte to C,H,W
img_arr.shape
# Out:
# (236, 320, 3)

# %%
# first converte to torc array
img = torch.from_numpy(img_arr)

out = img.permute(2,0,1)

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
batch_size = 734

batch = torch.zeros(batch_size, 3,134,140, dtype = torch.uint8)

# %%
# plt.imshow(batch[0])

# %%
data_dir = '/home/mikey/Downloads/flowers/sunflower'

names = [name for name in os.listdir(data_dir)
            if os.path.splitext(name)[-1] == '.jpg'
        ]
for i, filename in enumerate(names):
    img_arr = imageio.imread(os.path.join(data_dir, filename))
    img_t = torch.from_numpy(img_arr)
    img_t = img_t.permute(2,0,1)
    img_t = img_t[:,:134,:140]
    img_t = img_t[:3]
    batch[i] = img_t

# %%
plt.imshow(batch[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-3d4f49bc44e7> in <module>
# ----> 1 plt.imshow(batch[0])
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
# ...

# %%
img_t.resize_as()
